# %% [markdown]
# #### Oficial
# https://www.python.org/
#
# #### Repositorio de bibliotecas
# https://pypi.org/
#
# #### Problemas de biliotecas en windows
# - **pip - binary:** pip install biblioteca --only-binary biblioteca
#
# - **GnuWin:** Instaladores de bibliotecas ya compiladas parasistemas Windows, útil para dependencias
#
#     https://gnuwin32.sourceforge.net/
#
# - Unofficial Windows Binaries for Python Extension Packages
#
#     https://www.lfd.uci.edu/~gohlke/pythonlibs/
#
# #### Aprendizaje
#
# - **Python for Beginners:** nivel principiante
#
#     https://www.pythonforbeginners.com/
#
# - **Learn Python:** aprendizaje interactivo
#
#     https://www.learnpython.org/
#
# - **Google’s Python Class:** tutorial avanzado de aplicaciones modernas
#
#     https://developers.google.com/edu/python/
#
# - **Python Spot:** temas varios de python (bases de datos, wb, redes, juegos...)
#
#     https://pythonspot.com/
#
# - **Full Stack Python:** recursos para todo tipo de nivel
#
#     https://www.fullstackpython.com/
#
# - **Real Python:** recursos con podcast e itinerario de aprendizaje
#
#     https://realpython.com/
#
# - **Talk Python:** Podcasts semanales sobre las noticias más recientes del lenguaje de programación
#
#     https://talkpython.fm/
#
# #### Libros
# - **A Byte of Python:** Libro para principiantes
#
#     https://python.swaroopch.com/
#
# - **The Hitchhiker’s Guide to Python:** libro a todo tipo de niveles
#
#     https://docs.python-guide.org/
#
# #### EXTRA
# ##### Tiobe
# - Top lenguajes más empleados
# https://www.tiobe.com/tiobe-index/
#
# #### Python en Spotify
# https://engineering.atspotify.com/2013/03/how-we-use-python-at-spotify/
#
# #### Python en Instagram
# https://instagram-engineering.com/web-service-efficiency-at-instagram-with-python-4976d078e366
